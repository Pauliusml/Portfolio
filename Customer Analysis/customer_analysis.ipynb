# %% [markdown]
# <font size="5">Customer Analysis</font><br>
#
# There are many problems business has to overcome to achieve its goals.<br>
# Some of them are customer related.<br>
# How to reach them? What to recommend them?<br>
# And probably the most important, how to make it effectively?<br>
# Marketing costs a lot of money and time, offering the wrong product to the wrong people on the wrong time<br>
# can be not only wastefull but also cause some damage if customers lose trust and makes negative impression<br>
# about the company in general.<br>
# <br>
# In this example we will try to build a model, which analysis customers and tries to reveal their potential, so<br>
# the marketing team could build more effective marketing campaigns.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression as lr
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
import tensorflow as tf
from keras.regularizers import l1_l2
from tensorflow.keras.callbacks import EarlyStopping
import joblib

# %% [markdown]
# Firstly, we will load the data and rename some columns with more friendly names.<br>
# (There is a description file in the folder alongside .csv)

# %%
data = pd.read_csv('marketing_campaign.csv', sep = '\t')
data = data.drop_duplicates()
data = data.dropna()
data.rename(columns = {'NumWebPurchases':'Web', 'NumCatalogPurchases':'Catalogue', 'NumStorePurchases':'Store','MntWines':'Wines', 'Dt_Customer':'Customer_tenure',
                       'MntFruits':'Fruits', 'MntMeatProducts':'Meat', 'MntFishProducts':'Fish', 'MntSweetProducts':'Sweet', 'MntGoldProds':'Gold'}, inplace=True)

# %% [markdown]
# Now we will check if it is historical data containing customer history, or just general information about them

# %%
print('Total unique customers IDs:', len(data.apply(np.unique, axis = 0)['ID']))
print('Total data points:', len(data))
# Out:
# Total unique customers IDs: 2216
# Total data points: 2216

# %% [markdown]
# Unique IDs and total data points count is the same, indicating that data contains general information about the customers.<br>
# <br>
# Now lets dive in to the features.
# Some of the features are categorical, and we need to convert to numerical.<br>
# Some features are dates, we need to convert them to numerically interpretable forms<br>
# for example, date of birth should be converted to age.<br>
# Also, we need to check if data is valid and clean if needed.

# %%
plt.hist(data['Year_Birth'], bins = 20)
plt.title('Birth date distribution')
plt.ylabel('Customer quantity')
plt.xlabel('Customer Birth date')
plt.show()

# %% [markdown]
# Dates look normaly distributed, except for those around 1900 year.<br>
# I don't think that these customers are over a 100 years old. Even though they were, they do not represent clear group<br>
# and act more like an outliers.

# %%
plt.hist(data['Income'], bins = 20)
plt.title('Income distribution')
plt.ylabel('Customer quantity')
plt.xlabel('Customer Income')
plt.show()

# %% [markdown]
# We see similar situation with income. Most values are between 0 and 100000, but one is over 600000.<br>
# For the same reason as before we will treat it as an outlier.<br>

# %%
plt.bar(data['Education'].unique(), data['Education'].value_counts().values)
plt.title('Education distribution')
plt.ylabel('Customer quantity')
plt.xlabel('Customer Education')
plt.show()

# %% [markdown]
# We can see that most customers has higher education, there is also '2n Cycle' value, which is equivalent<br>
# to 'Master' so I will just merge them. Also, we need to convert data to numerical.

# %%
data['Education'] = data['Education'].replace('2n Cycle', 'Master')
data['Education'] = data['Education'].map({'Basic': 1, 'Graduation': 2, 'Master': 3, 'PhD': 4})

# %%
# Also we need to convert date of birth to actual age.
data['Age'] = 2024-data['Year_Birth']
data = data[data['Age'] < 100]

# %%
# Also, we have marital status.
plt.figure(figsize=(8, 5))
plt.bar(data['Marital_Status'].unique(), data['Marital_Status'].value_counts().values)
plt.title('Relationship status distribution')
plt.ylabel('Customer quantity')
plt.xlabel('Customer relationship status')
plt.show()

# %% [markdown]
# As we can see, we also have some incorrect data. 'Absurd', 'YOLO'. Also, 'Alone' is not very clear, might be single might be divorced.<br>
# As there is not that much of them, I will just remove it together with incorrect ones.

# %%
data['Marital_Status'] = data['Marital_Status'].apply(lambda x: 0 if x in ['Alone', 'Absurd', 'YOLO'] else x)
data = data[data['Marital_Status'] != 0]

# %% [markdown]
# Beside that, we need to convert them to numeric values, but<br>
# features does not have clear hierarchical structure. For example, together and married can be living together so might fall into the same group.<br>
# Divorced and widowed are also single, so you might just categorize, single or not.<br>
# But there might be hidden psychological information like customer value system and lifestyle.<br>
# So, I prefer one hot encoding.

# %%
encoder = OneHotEncoder(sparse_output=False)
marital_status = encoder.fit_transform(data[['Marital_Status']])
marital_status = pd.DataFrame(marital_status, columns = encoder.categories_[0])
data.reset_index(drop=True, inplace=True)
marital_status.reset_index(drop=True, inplace=True)
data = pd.concat([data, marital_status], axis=1)
data = data.drop(['Marital_Status'], axis = 1)

# %%
# Another feature to look into is 'Customer_tenure', which shows when customer registered.
# We need it to convert it to total time being the customer.
data['Customer_tenure'] = data['Customer_tenure'].apply(lambda x: 2024 - int(x[-4:])).values

# %% [markdown]
# Now to find other outliers, which might negatively affect our data, we will be using IsolationForest algorithm

# %%
from sklearn.ensemble import IsolationForest
forest = IsolationForest(contamination=0.01)
for i in data.columns:
    anomaly = forest.fit_predict(data[[i]])
    data = data[anomaly != -1]

# %% [markdown]
# Lets see what we have after cleaning

# %%
plt.hist(data['Age'], bins = 10)
plt.title('Age')
plt.ylabel('Customer quantity')
plt.xlabel('Age')
plt.show()

plt.hist(data['Income'], bins = 10)
plt.title('Income distribution')
plt.ylabel('Customer quantity')
plt.xlabel('Customer Income')
plt.show()

# %% [markdown]
# We can see that outliers are gone and data is more normaly distributed.<br>
# As we have cleaned our data, lets see what we can get from it. Firstly lets look into Purchase channels, like web, catalogue or store.

# %%
sorted = data[['Web', 'Catalogue', 'Store']].sum().sort_values(ascending = False)
title = 'Distribution of Purchases by channel type'
plt.bar(sorted.index.values, (sorted.values/sorted.sum()) * 100)
plt.title(title)
plt.ylabel('Percent, %')
plt.xlabel('Customer purchase channel')
# Out:
# Text(0.5, 0, 'Customer purchase channel')

# %% [markdown]
# Seems that most of the purchases are made in store more than 40 %, and least is made using orders from catalogues, about 20%<br>
# Web purchases landed in the middle, more than 30 %<br>
# Now we can try to find out who is using which channel. I will be using Correalation matrix.

# %%
correlation_matrix = data[['Age', 'Education', 'Single', 'Together', 'Married',
                           'Divorced', 'Widow','Income', 'Kidhome', 'Teenhome',
                           'Customer_tenure', 'Recency', 'Complain','Web',
                           'Catalogue', 'Store', 'NumWebVisitsMonth']].corr()

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(round(correlation_matrix, 2), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Interesting. Complain doesn't have any values. it might be empty.

# %%
plt.plot(data['Complain'])

# %% [markdown]
# Yes, all values seems to be 0, so I will drop this column, also there are many values with little to no correalation<br>
# so, for easier read purpose I will remove them from the matrix

# %%
data = data.drop('Complain', axis = 1)

# %%
correlation_matrix = data[['Age','Income', 'Kidhome', 'Teenhome',
                           'Customer_tenure', 'Web', 'Store', "Catalogue",'NumWebVisitsMonth']].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(round(correlation_matrix, 2), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Age is slightly correlated with all three channels, which means there is no choice among them but it is correlated with more purchases overall.<br>
# It might be because age is positively correlated with income, and income is strongly correlated with purchases.<br>
# The strongest correlations are with Income, Kidhome, Teenhome, Customer_tenure, Number of WEb visits.<br>
# Income is positevly correlated with all channels and is negatively correlated with web visits per month. Which means that more wealthy people consume more, and people with low income tend to use web more.<br>
# Interestingly more web visits are not correlated with more web purchasis. What suggests that customer is just checking, probably looking for good deals or maybe did not find what were looking for?<br>
# Kidhome is negatively correlated with purchases and income. But positively correlated to web visits. It makes sense, because there is probably stay at home parent, who doesnt work, and prefers shopping<br>
# from home because is taking care of the kid. As having a kid is negatively correalated to income it suggest that web is just checked to hunt better deals.<br>
# Teenhome is slightly positively correlated with web visits and purchases, and negatively correlated to catalog purchases. Which might show that teenagers might influence the parents and that younger people<br>
# prefer web purchasing.<br>
# Customer tenure positively correlates to web purchases and web visits. It seems that new customers are more likely to go to store or to use catalogs. It is difficult to say what is the reason for it, I could speculate<br>
# that it is influenced by the nature how they found out about the shop, for example from catalogues, so they more prone to use them at first till they find out about web services. Or just convenience of the location of the store.<br>
# Other speculation could be that people are cautious about newly found shop and prefer buying at the store at first, actualy trying/inspecting the product and tend to use web shop when they develope trust.<br>

# %%
# lets remove irrelevant features
correlation_matrix = data[['Education', 'Single','Income', 'Kidhome', 'Teenhome', 'Customer_tenure', 'Wines',
                           'Fruits', 'Meat', 'Fish', 'Sweet', 'Gold']].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(round(correlation_matrix, 2), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Product consumption type matrix')
plt.show()

# %% [markdown]
# Correlation matrix above supposed to reveal type of products different customers choose.<br>
# We can see that higher income is more correlated to meat and whine consuming, also these two products tend to correlate, so meat and whine might be purchased together.<br>
# But we don't have data of the customer carts to confirm that.<br>
# Also we can see that people with kids are less likely to purchase wine and more likely to purchase fruits.<br>
# People with teenagers seems to tend to sweet products and fruits and least likely to consume meat.<br>

# %% [markdown]
# Now lets see who are more likely to participate in advertising campaigns.<br>
# We don't have information about separate marketing campaigns, so we just sum up how many in total customer was involved.<br>

# %%
data['Accepted_campaigns'] = data[['AcceptedCmp1', 'AcceptedCmp2', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'Response']].sum(axis = 1)

# %%
correlation_matrix = data[['Income', 'Kidhome', 'Teenhome', 'Customer_tenure', 'Recency', 
                           'NumDealsPurchases', 'Accepted_campaigns']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(round(correlation_matrix, 2), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Marketing Campaigns')
plt.show()

# %% [markdown]
# As previously most important features are income, and children at home.<br>
# We can see that people with kids and teenagers are more likely to pursue discounts.<br>
# People with higher income tend to participate in promotion campaigns.<br>
# People with children seem to be opposite and participate less. Would be interesting to see why is that, but we don't have any info about those promotions.<br>
# I could speculate that either they do not contain products of interest, or that to participate you have to physicaly attend some places and people with children<br>
# have limited ability to do so. But, again, it is just speculation.<br>

# %%
stopper
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 stopper
#
# NameError: name 'stopper' is not defined

# %% [markdown]
# Now we will build regression model to evaluate customer consumption.<br>
# Regression model will show an average amount for every product category and we will be able to see<br>
# who falls short and who consumes more.

# %%
def linear_regression_training(scaled_data, target):
    X_train, X_validate, y_train, y_validate = train_test_split(scaled_data, target, test_size=0.2)

    lr_wines = lr()
    lr_wines.fit(X_train, y_train)

    training_prediction = lr_wines.predict(X_train)
    validation_prediction = lr_wines.predict(X_validate)

    training_mae = mean_absolute_error(training_prediction, y_train)
    validation_mae = mean_absolute_error(validation_prediction, y_validate)

    print('Training MAE:', round(training_mae, 2), training_mae/max(training_prediction))
    print('Validation MAE:', round(validation_mae))

    return {'training_prediction':training_prediction, 'validation_prediction':validation_prediction, 'training_mae':training_mae, 'validation_mae':validation_mae, 'model':lr_wines}

# %%
data_scaler = StandardScaler()
scaled_data = data_scaler.fit_transform(data[['Age', 'Education', 'Single', 'Together', 'Married', 'Divorced', 'Widow','Income', 'Kidhome', 'Teenhome', 'Customer_tenure', 'Recency', 
                           'NumDealsPurchases', 'Accepted_campaigns', 'Store', 'Web', 'Catalogue']])
# poly = PolynomialFeatures(2)
# scaled_data = poly.fit_transform(scaled_data)


target_scaler = StandardScaler()
scaled_target = target_scaler.fit_transform(data[['Wines','Fruits', 'Meat', 'Fish', 'Sweet', 'Gold']])

purchase_prediction = {}
n = 0
for i in ['Wines','Fruits', 'Meat', 'Fish', 'Sweet', 'Gold']:
    print(i)
    purchase_prediction[i] = linear_regression_training(scaled_data, scaled_target[:,n])
    n += 1
# Out:
# Wines
# Training MAE: 0.36 0.14049518760809324
# Validation MAE: 0
# Fruits
# Training MAE: 0.5 0.2749628369330738
# Validation MAE: 1
# Meat
# Training MAE: 0.36 0.15242731496005862
# Validation MAE: 0
# Fish
# Training MAE: 0.5 0.26015688525908665
# Validation MAE: 0
# Sweet
# Training MAE: 0.49 0.26408143257055106
# Validation MAE: 1
# Gold
# Training MAE: 0.55 0.3723856893851053
# Validation MAE: 1

# %%
regularization = l1_l2(l1=0.01, l2=0.01)

dnn = {}
products = ['Wines','Fruits', 'Meat', 'Fish', 'Sweet', 'Gold']
for i in range(6):
    model = Sequential([
    Input((17,)),
    Dense(32, activation = 'tanh', kernel_regularizer = regularization),
    Dense(32, activation = 'tanh', kernel_regularizer = regularization),
    Dense(32, activation = 'tanh', kernel_regularizer = regularization),
    Dense(1),
    ])



    optimizer = tf.keras.optimizers.Adam(learning_rate=0.02)

    model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = ['mae'])
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=250,
        min_delta=0.001,
        restore_best_weights=True 
    )
    model.fit(scaled_data, scaled_target[:,i], validation_split=0.2, epochs = 1500, batch_size = 2000, callbacks=[early_stopping])
    dnn[products[i]] = model
# Out:
# Epoch 1/1500
# 1/1 [==============================] - 1s 1s/step - loss: 6.5371 - mae: 1.0234 - val_loss: 6.3836 - val_mae: 0.9788
# Epoch 2/1500
# 1/1 [==============================] - 0s 26ms/step - loss: 6.3762 - mae: 0.9670 - val_loss: 6.2320 - val_mae: 0.9234
# Epoch 3/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 6.2289 - mae: 0.9140 - val_loss: 6.0942 - val_mae: 0.8716
# Epoch 4/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 6.0942 - mae: 0.8640 - val_loss: 5.9689 - val_mae: 0.8226
# Epoch 5/1500
# 1/1 [==============================] - 0s 26ms/step - loss: 5.9721 - mae: 0.8174 - val_loss: 5.8556 - val_mae: 0.7768
# Epoch 6/1500
# 1/1 [==============================] - 0s 26ms/step - loss: 5.
- mae: 0.5246 - val_loss: 0.6780 - val_mae: 0.5198
# Epoch 1462/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.6807 - mae: 0.5245 - val_loss: 0.6780 - val_mae: 0.5201
# Epoch 1463/1500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.6807 - mae: 0.5248 - val_loss: 0.6780 - val_mae: 0.5199
# Epoch 1464/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.6806 - mae: 0.5245 - val_loss: 0.6781 - val_mae: 0.5200
# Epoch 1465/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6807 - mae: 0.5246 - val_loss: 0.6781 - val_mae: 0.5200
# Epoch 1466/1500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.6807 - mae: 0.5247 - val_loss: 0.6781 - val_mae: 0.5199
# Epoch 1467/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.6807 - mae: 0.5245 - val_loss: 0.6781 - val_mae: 0.5200
# Epoch 1468/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6807 - mae: 0.5247 - val_loss: 0.6781 - val_mae: 0.5199
# Epoch 1469/1500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6807 - mae: 0.5246 - val_loss: 0.6780 - val_mae: 0.5199
# Epoch 1470/1500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6806 - mae: 0.5246 - val_loss: 0.6781 - val_mae: 0.5199
# Epoch 1471/1500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.6807 - mae: 0.5246 - val_loss: 0.6780 - val_mae: 0.5199
# Epoch 1472/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.6806 - mae: 0.5246 - val_loss: 0.6779 - val_mae: 0.5199
# Epoch 1473/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6805 - mae: 0.5246 - val_loss: 0.6780 - val_mae: 0.5199
# Epoch 1474/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6805 - mae: 0.5246 - val_loss: 0.6780 - val_mae: 0.5200
# Epoch 1475/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.6805 - mae: 0.5246 - val_loss: 0.6780 - val_mae: 0.5201
# Epoch 1476/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6805 - mae: 0.5248 - val_loss: 0.6778 - val_mae: 0.5198
# Epoch 1477/1500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.6805 - mae: 0.5245 - val_loss: 0.6779 - val_mae: 0.5200
# Epoch 1478/1500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.6805 - mae: 0.5246 - val_loss: 0.6780 - val_mae: 0.5201
# Epoch 1479/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6804 - mae: 0.5248 - val_loss: 0.6780 - val_mae: 0.5198
# Epoch 1480/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6805 - mae: 0.5244 - val_loss: 0.6781 - val_mae: 0.5201
# Epoch 1481/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.6805 - mae: 0.5248 - val_loss: 0.6781 - val_mae: 0.5200
# Epoch 1482/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6805 - mae: 0.5247 - val_loss: 0.6780 - val_mae: 0.5199
# Epoch 1483/1500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.6805 - mae: 0.5246 - val_loss: 0.6780 - val_mae: 0.5200
# Epoch 1484/1500
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6804 - mae: 0.5247 - val_loss: 0.6780 - val_mae: 0.5200
# Epoch 1485/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.6804 - mae: 0.5246 - val_loss: 0.6780 - val_mae: 0.5201
# Epoch 1486/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6804 - mae: 0.5247 - val_loss: 0.6779 - val_mae: 0.5200
# Epoch 1487/1500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.6803 - mae: 0.5246 - val_loss: 0.6779 - val_mae: 0.5200
# Epoch 1488/1500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.6803 - mae: 0.5247 - val_loss: 0.6779 - val_mae: 0.5200
# Epoch 1489/1500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.6803 - mae: 0.5246 - val_loss: 0.6779 - val_mae: 0.5200
# Epoch 1490/1500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.6804 - mae: 0.5247 - val_loss: 0.6779 - val_mae: 0.5200
# Epoch 1491/1500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.6803 - mae: 0.5246 - val_loss: 0.6779 - val_mae: 0.5200
# Epoch 1492/1500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.6803 - mae: 0.5246 - val_loss: 0.6780 - val_mae: 0.5201
# Epoch 1493/1500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.6803 - mae: 0.5246 - val_loss: 0.6780 - val_mae: 0.5200
# Epoch 1494/1500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.6803 - mae: 0.5247 - val_loss: 0.6780 - val_mae: 0.5199
# Epoch 1495/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.6803 - mae: 0.5245 - val_loss: 0.6781 - val_mae: 0.5202
# Epoch 1496/1500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.6803 - mae: 0.5248 - val_loss: 0.6779 - val_mae: 0.5199
# Epoch 1497/1500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6803 - mae: 0.5245 - val_loss: 0.6779 - val_mae: 0.5200
# Epoch 1498/1500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.6803 - mae: 0.5246 - val_loss: 0.6778 - val_mae: 0.5202
# Epoch 1499/1500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.6802 - mae: 0.5248 - val_loss: 0.6777 - val_mae: 0.5197
# Epoch 1500/1500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6802 - mae: 0.5244 - val_loss: 0.6778 - val_mae: 0.5201

# %%
X_train, X_validate, y_train, y_validate = train_test_split(scaled_data, scaled_target, test_size=0.2, shuffle=False)

# %%
mae_dnn = []
mae_lr = []
for i, key in zip(range(6), products):
    print(key)
    pred = dnn[key].predict(X_validate)
    mae_dnn.append(round(mean_absolute_error(pred, y_validate[:,i]),2))
    mae_lr.append(round(mean_absolute_error(purchase_prediction[key]['model'].predict(X_validate), y_validate[:,i]),2))
print(mae_dnn)
print(mae_lr)

position = np.arange(len(mae_dnn))
width = 0.35
multiplier = 0
mae = [mae_dnn, mae_lr]
label = ['DNN', 'LR']
colors = ['slategrey', 'lightsteelblue']
for i in range(2):
    plt.bar(position + width*multiplier, mae[i], width = width, label = label[i], color = colors[i])
    multiplier += 1

plt.xticks(position + width/2, products)
plt.title('Validation MAE comparison\n(lower is better)')
plt.xlabel('Product')
plt.ylabel('MAE')
plt.legend()
# Out:
# Wines
# 12/12 [==============================] - 0s 1ms/step
# Fruits
# 12/12 [==============================] - 0s 1ms/step
# Meat
# 12/12 [==============================] - 0s 1ms/step
# Fish
# 12/12 [==============================] - 0s 1ms/step
# Sweet
# 12/12 [==============================] - 0s 1ms/step
# Gold
# 12/12 [==============================] - 0s 1ms/step
# [0.27, 0.45, 0.27, 0.43, 0.42, 0.52]
# [0.34, 0.5, 0.37, 0.49, 0.46, 0.54]

# %% [markdown]
# I built two models - based on linear regression (LR) and deep neural network (DNN).<br>
# As we can see above DNN performed better in all product categories.<br>
# Lets inspect the results visualy.

# %%
for i in range(len(products)):
    temp_lr = pd.DataFrame()
    temp_dnn = pd.DataFrame()
    temp_dnn['predicted'] = dnn[products[i]].predict(scaled_data).flatten()
    temp_lr['predicted'] = purchase_prediction[products[i]]['model'].predict(scaled_data)
    temp_dnn['actual'] = scaled_target[:,i]
    temp_lr['actual'] = scaled_target[:,i]
    temp_dnn = temp_dnn.sort_values(['predicted'], ascending = True).reset_index()
    temp_lr = temp_lr.sort_values(['predicted'], ascending = True).reset_index()

    f, ax = plt.subplots(1,2, figsize = (16, 6))
    ax[0].scatter(range(0,len(temp_dnn)), temp_dnn['actual'])
    ax[0].plot(range(0,len(temp_dnn)), temp_dnn['predicted'], color = 'red')
    ax[0].set_xlabel('Training examples')
    ax[0].set_ylabel('Standard deviation')
    ax[0].set_title(f'DNN {products[i]}')
    ax[0].legend(['Actual values', 'Predicted values'])

    ax[1].scatter(range(0,len(temp_lr)), temp_lr['actual'])
    ax[1].plot(range(0,len(temp_lr)), temp_lr['predicted'], color = 'red')
    ax[1].set_xlabel('Training examples')
    ax[1].set_ylabel('Standard deviation')
    ax[1].set_title(f'Linear Regression {products[i]}')
    ax[1].legend(['Actual values', 'Predicted values'])
# Out:
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step

# %% [markdown]
# DNN seems to better fit extreme values (lowest, highest) and fits the shape very well.<br>
# So, I will use DNN model from now on, and we could try some parameter tuning to find best solutions<br>
# for each product individually. I will use randomized search to look for better models.

# %% [markdown]
# We have 6 models, doing randomized search might take a while.<br>
# I built optimization.py for randomized search which will be using multiprocessing to increase speed.<br>
# Parameters will be saved to 'optimized_parameters.joblib' file.<br>

# %%
#saving scaled data for training
joblib.dump(scaled_data, 'scaled_data.sav')
joblib.dump(scaled_target, 'scaled_target.sav')
# Out:
# ['scaled_target.sav']

# %%
# loading optimized parameters
optimized = joblib.load('optimized_parameters.joblib')

# %%
# model building function according to found parameters
def dnn_model(layers = 3, neurons = 32, activation = 'tanh', learning_rate = 0.02, regularization = 0.01, input_shape = (17,)):
    reg = l1_l2(l1=regularization, l2=regularization)
    model = Sequential()
    model.add(Input(input_shape))
    for l in range(layers):
        model.add(Dense(neurons, activation = activation, kernel_regularizer = reg)),
    model.add(Dense(1))
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer = optimizer, loss = 'mean_squared_error')
    return model

# %%
# building new models
optimized_models = {}
for i in range(6):
    optimized_models[products[i]] = dnn_model(layers = optimized[i][products[i]]['layers'], neurons = optimized[i][products[i]]['layers'], activation = optimized[i][products[i]]['activation'],
                                              learning_rate=optimized[i][products[i]]['learning_rate'], regularization=optimized[i][products[i]]['regularization'])

# %%
# training
for i in range(6):
    optimized_models[products[i]].fit(scaled_data, scaled_target[:,i], validation_split = 0.2, epochs = 1500, batch_size = 2000, callbacks = [early_stopping])
# Out:
# Epoch 1/1500
# 1/1 [==============================] - 0s 297ms/step - loss: 3.1172 - val_loss: 2.9001
# Epoch 2/1500
# 1/1 [==============================] - 0s 32ms/step - loss: 2.9632 - val_loss: 2.7639
# Epoch 3/1500
# 1/1 [==============================] - 0s 35ms/step - loss: 2.8183 - val_loss: 2.6361
# Epoch 4/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 2.6820 - val_loss: 2.5176
# Epoch 5/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 2.5544 - val_loss: 2.4060
# Epoch 6/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 2.4338 - val_loss: 2.3017
# Epoch 7/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 2.3210 - val_loss: 2.2053
# Epoch 8/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 2.2156 - val_loss: 2.1162
# Epoch 9/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 2.1180 - val_loss: 2.0321
# Epoch 10/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 2.0260 - val_loss: 1.9554
# Epoch 11/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 1.9426 - val_loss: 1.8835
# Epoch 12/1500
# 1/1 [==============================] - 0s 32ms/step - loss: 1.8648 - val_loss: 1.8162
# Epoch 13/1500
# 1/1 [==============================] - 0s 32ms/step - loss: 1.7924 - val_loss: 1.7551
# Epoch 14/1500
# 1/1 [==============================] - 0s 28ms/step - loss: 1.7260 - val_loss: 1.6985
# Epoch 15/1500
# 1/1 [==============================] - 0s 32ms/step - loss: 1.6647 - val_loss: 1.6460
# Epoch 16/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 1.6081 - val_loss: 1.5983
# Epoch 17/1500
# 1/1 [==============================] - 0s 33ms/step - loss: 1.5569 - val_loss: 1.5543
# Epoch 18/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 1.5097 - val_loss: 1.5136
# Epoch 19/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 1.4663 - val_loss: 1.4754
# Epoch 20/1500
# 1/1 [==============================] - 0s 33ms/step - loss: 1.4258 - val_loss: 1.4409
# Epoch 21/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 1.3897 - val_loss: 1.4083
# Epoch 22/1500
# 1/1 [==============================] - 0s 28ms/step - loss: 1.3562 - val_loss: 1.3791
# Epoch 23/1500
# 1/1 [==============================] - 0s 35ms/step - loss: 1.3260 - val_loss: 1.3524
# Epoch 24/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 1.2984 - val_loss: 1.3276
# Epoch 25/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 1.2730 - val_loss: 1.3052
# Epoch 26/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 1.2501 - val_loss: 1.2845
# Epoch 27/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 1.2291 - val_loss: 1.2657
# Epoch 28/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 1.2100 - val_loss: 1.2480
# Epoch 29/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 1.1923 - val_loss: 1.2318
# Epoch 30/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 1.1763 - val_loss: 1.2167
# Epoch 31/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 1.1615 - val_loss: 1.2027
# Epoch 32/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 1.1480 - val_loss: 1.1893
# Epoch 33/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 1.1350 - val_loss: 1.1772
# Epoch 34/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 1.1233 - val_loss: 1.1654
# Epoch 35/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 1.1122 - val_loss: 1.1546
# Epoch 36/1500
# 1/1 [==============================] - 0s 26ms/step - loss: 1.1020 - val_loss: 1.1440
# Epoch 37/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 1.0922 - val_loss: 1.1342
# Epoch 38/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 1.0832 - val_loss: 1.1246
# Epoch 39/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 1.0744 - val_loss: 1.1155
# Epoch 40/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 1.0662 - val_loss: 1.1069
# Epoch 41/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 1.0585 - val_loss: 1.0981
# Epoch 42/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 1.0508 - val_loss: 1.0897
# Epoch 43/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 1.0434 - val_loss: 1.0817
# Epoch 44/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 1.0363 - val_loss: 1.0737
# Epoch 45/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 1.0293 - val_loss: 1.0661
# Epoch 46/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 1.0228 - val_loss: 1.0587
# Epoch 47/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 1.0162 - val_loss: 1.0515
# Epoch 48/1500
# 1/1 [==============================] - 0s 28ms/step - loss: 1.0098 - val_loss: 1.0444
# Epoch 49/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 1.0037 - val_loss: 1.0375
# Epoch 50/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.9976 - val_loss: 1.0311
# Epoch 51/1500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9919 - val_loss: 1.0248
# Epoch 52/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.9863 - val_loss: 1.0186
# Epoch 53/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.9808 - val_loss: 1.0128
# Epoch 54/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.9755 - val_loss: 1.0070
# Epoch 55/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.9703 - val_loss: 1.0014
# Epoch 56/1500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.9651 - val_loss: 0.9960
# Epoch 57/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.9602 - val_loss: 0.9905
# Epoch 58/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.9552 - val_loss: 0.9851
# Epoch 59/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.9504 - val_loss: 0.9800
# Epoch 60/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.9457 - val_loss: 0.9747
# Epoch 61/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.9410 - val_loss: 0.9696
# Epoch 62/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.9365 - val_loss: 0.9647
# Epoch 63/1500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.9320 - val_loss: 0.9599
# Epoch 64/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.9276 - val_loss: 0.9552
# Epoch 65/1500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.9232 - val_loss: 0.9503
# Epoch 66/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9189 - val_loss: 0.9456
# Epoch 67/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.9147 - val_loss: 0.9410
# Epoch 68/1500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.9105 - val_loss: 0.9364
# Epoch 69/1500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.9063 - val_loss: 0.9318
# Epoch 70/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.9022 - val_loss: 0.9273
# Epoch 71/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.8981 - val_loss: 0.9228
# Epoch 72/1500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.8941 - val_loss: 0.9187
# Epoch 73/1500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.8901 - val_loss: 0.9143
# Epoch 74/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8861 - val_loss: 0.9101
# Epoch 75/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.8820 - val_loss: 0.9058
# Epoch 76/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.8778 - val_loss: 0.9017
# Epoch 77/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.8738 - val_loss: 0.8975
# Epoch 78/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.8698 - val_loss: 0.8932
# Epoch 79/1500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.8657 - val_loss: 0.8890
# Epoch 80/1500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.8616 - val_loss: 0.8848
# Epoch 81/1500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8576 - val_loss: 0.8804
# Epoch 82/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.8536 - val_loss: 0.8762
# Epoch 83/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.8496 - val_loss: 0.8718
# Epoch 84/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8457 - val_loss: 0.8674
# Epoch 85/1500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.8417 - val_loss: 0.8629
# Epoch 86/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.8378 - val_loss: 0.8583
# Epoch 87/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8338 - val_loss: 0.8538
# Epoch 88/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.8298 - val_loss: 0.8492
# Epoch 89/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.8258 - val_loss: 0.8446
# Epoch 90/1500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.8219 - val_loss: 0.8399
# Epoch 91/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.8178 - val_loss: 0.8352
# Epoch 92/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.8137 - val_loss: 0.8305
# Epoch 93/1500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.8097 - val_loss: 0.8256
# Epoch 94/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.8056 - val_loss: 0.8204
# Epoch 95/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.8014 - val_loss: 0.8155
# Epoch 96/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.7974 - val_loss: 0.8105
# Epoch 97/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.7933 - val_loss: 0.8054
# Epoch 98/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.7892 - val_loss: 0.8004
# Epoch 99/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.7850 - val_loss: 0.7953
# Epoch 100/1500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.7809 - val_loss: 0.7902
# Epoch 101/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.7769 - val_loss: 0.7850
# Epoch 102/1500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.7728 - val_loss: 0.7800
# Epoch 103/1500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.7687 - val_loss: 0.7748
# Epoch 104/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.7646 - val_loss: 0.7696
# Epoch 105/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.7605 - val_loss: 0.7644
# Epoch 106/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.7564 - val_loss: 0.7594
# Epoch 107/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.7524 - val_loss: 0.7543
# Epoch 108/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.7484 - val_loss: 0.7493
# Epoch 109/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.7444 - val_loss: 0.7443
# Epoch 110/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.7404 - val_loss: 0.7392
# Epoch 111/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.7364 - val_loss: 0.7343
# Epoch 112/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.7325 - val_loss: 0.7293
# Epoch 113/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.7286 - val_loss: 0.7244
# Epoch 114/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.7247 - val_loss: 0.7195
# Epoch 115/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.7208 - val_loss: 0.7146
# Epoch 116/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.7170 - val_loss: 0.7099
# Epoch 117/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.7133 - val_loss: 0.7051
# Epoch 118/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.7095 - val_loss: 0.7004
# Epoch 119/1500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.7058 - val_loss: 0.6957
# Epoch 120/1500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.7021 - val_loss: 0.6911
# Epoch 121/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.6985 - val_loss: 0.6866
# Epoch 122/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.6949 - val_loss: 0.6821
# Epoch 123/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.6914 - val_loss: 0.6776
# Epoch 124/1500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.6878 - val_loss: 0.6733
# Epoch 125/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6842 - val_loss: 0.6691
# Epoch 126/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6808 - val_loss: 0.6650
# Epoch 127/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.6774 - val_loss: 0.6609
# Epoch 128/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6740 - val_loss: 0.6569
# Epoch 129/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6706 - val_loss: 0.6529
# Epoch 130/1500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6672 - val_loss: 0.6490
# Epoch 131/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6639 - val_loss: 0.6452
# Epoch 132/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6606 - val_loss: 0.6414
# Epoch 133/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6574 - val_loss: 0.6376
# Epoch 134/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6543 - val_loss: 0.6340
# Epoch 135/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6512 - val_loss: 0.6304
# Epoch 136/1500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6482 - val_loss: 0.6270
# Epoch 137/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6453 - val_loss: 0.6237
# Epoch 138/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6424 - val_loss: 0.6204
# Epoch 139/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6395 - val_loss: 0.6173
# Epoch 140/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6368 - val_loss: 0.6143
# Epoch 141/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6342 - val_loss: 0.6113
# Epoch 142/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6316 - val_loss: 0.6082
# Epoch 143/1500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6292 - val_loss: 0.6051
# Epoch 144/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6268 - val_loss: 0.6021
# Epoch 145/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6244 - val_loss: 0.5992
# Epoch 146/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6221 - val_loss: 0.5965
# Epoch 147/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6199 - val_loss: 0.5937
# Epoch 148/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6177 - val_loss: 0.5910
# Epoch 149/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6155 - val_loss: 0.5884
# Epoch 150/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6135 - val_loss: 0.5858
# Epoch 151/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6115 - val_loss: 0.5831
# Epoch 152/1500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6095 - val_loss: 0.5804
# Epoch 153/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6076 - val_loss: 0.5778
# Epoch 154/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6057 - val_loss: 0.5752
# Epoch 155/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6039 - val_loss: 0.5726
# Epoch 156/1500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.6021 - val_loss: 0.5701
# Epoch 157/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6004 - val_loss: 0.5676
# Epoch 158/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.5987 - val_loss: 0.5652
# Epoch 159/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.5970 - val_loss: 0.5628
# Epoch 160/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.5953 - val_loss: 0.5604
# Epoch 161/1500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.5937 - val_loss: 0.5582
# Epoch 162/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.5921 - val_loss: 0.5559
# Epoch 163/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.5905 - val_loss: 0.5538
# Epoch 164/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.5889 - val_loss: 0.5518
# Epoch 165/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.5874 - val_loss: 0.5498
# Epoch 166/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.5859 - val_loss: 0.5479
# Epoch 167/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.5843 - val_loss: 0.5460
# Epoch 168/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.5828 - val_loss: 0.5443
# Epoch 169/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.5813 - val_loss: 0.5425
# Epoch 170/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.5797 - val_loss: 0.5407
# Epoch 171/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.5782 - val_loss: 0.5390
# Epoch 172/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.5766 - val_loss: 0.5375
# Epoch 173/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.5751 - val_loss: 0.5359
# Epoch 174/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.5736 - val_loss: 0.5343
# Epoch 175/1500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.5721 - val_loss: 0.5327
# Epoch 176/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.5707 - val_loss: 0.5310
# Epoch 177/1500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.5693 - val_loss: 0.5294
# Epoch 178/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.5679 - val_loss: 0.5279
# Epoch 179/1500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.5665 - val_loss: 0.5264
# Epoch 180/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.5652 - val_loss: 0.5249
# Epoch 181/1500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.5638 - val_loss: 0.5235
# Epoch 182/1500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.
1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.4502 - val_loss: 0.4134
# Epoch 311/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4493 - val_loss: 0.4125
# Epoch 312/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.4483 - val_loss: 0.4116
# Epoch 313/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.4474 - val_loss: 0.4108
# Epoch 314/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4464 - val_loss: 0.4099
# Epoch 315/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.4455 - val_loss: 0.4091
# Epoch 316/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.4445 - val_loss: 0.4083
# Epoch 317/1500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.4436 - val_loss: 0.4074
# Epoch 318/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.4427 - val_loss: 0.4065
# Epoch 319/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.4417 - val_loss: 0.4056
# Epoch 320/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.4408 - val_loss: 0.4048
# Epoch 321/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.4399 - val_loss: 0.4039
# Epoch 322/1500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.4389 - val_loss: 0.4029
# Epoch 323/1500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.4379 - val_loss: 0.4020
# Epoch 324/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.4370 - val_loss: 0.4010
# Epoch 325/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.4360 - val_loss: 0.4001
# Epoch 326/1500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4351 - val_loss: 0.3991
# Epoch 327/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4341 - val_loss: 0.3982
# Epoch 328/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4332 - val_loss: 0.3972
# Epoch 329/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.4323 - val_loss: 0.3963
# Epoch 330/1500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.4313 - val_loss: 0.3955
# Epoch 331/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4304 - val_loss: 0.3946
# Epoch 332/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4295 - val_loss: 0.3937
# Epoch 333/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.4285 - val_loss: 0.3929
# Epoch 334/1500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4276 - val_loss: 0.3920
# Epoch 335/1500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4266 - val_loss: 0.3911
# Epoch 336/1500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4257 - val_loss: 0.3901
# Epoch 337/1500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4247 - val_loss: 0.3892
# Epoch 338/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.4238 - val_loss: 0.3882
# Epoch 339/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.4228 - val_loss: 0.3874
# Epoch 340/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4219 - val_loss: 0.3865
# Epoch 341/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.4209 - val_loss: 0.3856
# Epoch 342/1500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.4200 - val_loss: 0.3847
# Epoch 343/1500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4190 - val_loss: 0.3839
# Epoch 344/1500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.4180 - val_loss: 0.3830
# Epoch 345/1500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4171 - val_loss: 0.3821
# Epoch 346/1500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4161 - val_loss: 0.3813
# Epoch 347/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.4151 - val_loss: 0.3804
# Epoch 348/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.4141 - val_loss: 0.3795
# Epoch 349/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4131 - val_loss: 0.3785
# Epoch 350/1500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.4121 - val_loss: 0.3777
# Epoch 351/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4110 - val_loss: 0.3768
# Epoch 352/1500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4100 - val_loss: 0.3760
# Epoch 353/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.4090 - val_loss: 0.3751
# Epoch 354/1500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4080 - val_loss: 0.3743
# Epoch 355/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.4070 - val_loss: 0.3734
# Epoch 356/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.4060 - val_loss: 0.3725
# Epoch 357/1500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4050 - val_loss: 0.3717
# Epoch 358/1500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.4040 - val_loss: 0.3708
# Epoch 359/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.4030 - val_loss: 0.3700
# Epoch 360/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4019 - val_loss: 0.3694
# Epoch 361/1500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4008 - val_loss: 0.3686
# Epoch 362/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3997 - val_loss: 0.3679
# Epoch 363/1500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3987 - val_loss: 0.3672
# Epoch 364/1500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3977 - val_loss: 0.3664
# Epoch 365/1500
# 1/1 [==============================] - 0s 27ms/step - loss: 0.3967 - val_loss: 0.3657
# Epoch 366/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3958 - val_loss: 0.3648
# Epoch 367/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3947 - val_loss: 0.3640
# Epoch 368/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3938 - val_loss: 0.3630
# Epoch 369/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3928 - val_loss: 0.3620
# Epoch 370/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3918 - val_loss: 0.3610
# Epoch 371/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3908 - val_loss: 0.3599
# Epoch 372/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3898 - val_loss: 0.3588
# Epoch 373/1500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3888 - val_loss: 0.3578
# Epoch 374/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3878 - val_loss: 0.3568
# Epoch 375/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3869 - val_loss: 0.3557
# Epoch 376/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3858 - val_loss: 0.3547
# Epoch 377/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3849 - val_loss: 0.3537
# Epoch 378/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3839 - val_loss: 0.3527
# Epoch 379/1500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3829 - val_loss: 0.3517
# Epoch 380/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3819 - val_loss: 0.3506
# Epoch 381/1500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.3809 - val_loss: 0.3497
# Epoch 382/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3800 - val_loss: 0.3488
# Epoch 383/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3789 - val_loss: 0.3479
# Epoch 384/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3780 - val_loss: 0.3470
# Epoch 385/1500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3771 - val_loss: 0.3461
# Epoch 386/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3762 - val_loss: 0.3452
# Epoch 387/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3753 - val_loss: 0.3443
# Epoch 388/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3744 - val_loss: 0.3435
# Epoch 389/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3735 - val_loss: 0.3428
# Epoch 390/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3727 - val_loss: 0.3420
# Epoch 391/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3718 - val_loss: 0.3411
# Epoch 392/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3709 - val_loss: 0.3402
# Epoch 393/1500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.3701 - val_loss: 0.3392
# Epoch 394/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3692 - val_loss: 0.3383
# Epoch 395/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3684 - val_loss: 0.3374
# Epoch 396/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3676 - val_loss: 0.3365
# Epoch 397/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3668 - val_loss: 0.3358
# Epoch 398/1500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3660 - val_loss: 0.3350
# Epoch 399/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3653 - val_loss: 0.3343
# Epoch 400/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3645 - val_loss: 0.3337
# Epoch 401/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3637 - val_loss: 0.3330
# Epoch 402/1500
# 1/1 [==============================] - 0s 25ms/step - loss: 0.3630 - val_loss: 0.3323
# Epoch 403/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3623 - val_loss: 0.3317
# Epoch 404/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3615 - val_loss: 0.3311
# Epoch 405/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3608 - val_loss: 0.3304
# Epoch 406/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3601 - val_loss: 0.3298
# Epoch 407/1500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.3594 - val_loss: 0.3292
# Epoch 408/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3587 - val_loss: 0.3286
# Epoch 409/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3580 - val_loss: 0.3279
# Epoch 410/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3573 - val_loss: 0.3272
# Epoch 411/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3566 - val_loss: 0.3267
# Epoch 412/1500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.3559 - val_loss: 0.3261
# Epoch 413/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3553 - val_loss: 0.3256
# Epoch 414/1500
# 1/1 [==============================] - 0s 22ms/step - loss: 0.3546 - val_loss: 0.3252
# Epoch 415/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3540 - val_loss: 0.3247
# Epoch 416/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3533 - val_loss: 0.3242
# Epoch 417/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3527 - val_loss: 0.3237
# Epoch 418/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3521 - val_loss: 0.3232
# Epoch 419/1500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3515 - val_loss: 0.3227
# Epoch 420/1500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3508 - val_loss: 0.3221
# Epoch 421/1500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.3502 - val_loss: 0.3214
# Epoch 422/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3496 - val_loss: 0.3209
# Epoch 423/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.3491 - val_loss: 0.3203
# Epoch 424/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3485 - val_loss: 0.3199
# Epoch 425/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3479 - val_loss: 0.3193
# Epoch 426/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3473 - val_loss: 0.3187
# Epoch 427/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3468 - val_loss: 0.3183
# Epoch 428/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3462 - val_loss: 0.3177
# Epoch 429/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3457 - val_loss: 0.3171
# Epoch 430/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3451 - val_loss: 0.3165
# Epoch 431/1500
# 1/1 [==============================] - 0s 21ms/step - loss: 0.3445 - val_loss: 0.3159
# Epoch 432/1500
# 1/1 [==============================] - 0s 24ms/step - loss: 0.3440 - val_loss: 0.3154
# Epoch 433/1500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.3434 - val_loss: 0.3149
# Epoch 434/1500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3429 - val_loss: 0.3145
# Epoch 435/1500
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3423 - val_loss: 0.3140
# Epoch 436/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3417 - val_loss: 0.3134
# Epoch 437/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3412 - val_loss: 0.3128
# Epoch 438/1500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.

# 1/1 [==============================] - 0s 27ms/step - loss: 0.6456 - val_loss: 0.6564
# Epoch 1210/1500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.6456 - val_loss: 0.6566
# Epoch 1211/1500
# 1/1 [==============================] - 0s 28ms/step - loss: 0.6456 - val_loss: 0.6570
# Epoch 1212/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.6455 - val_loss: 0.6574
# Epoch 1213/1500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6455 - val_loss: 0.6576
# Epoch 1214/1500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.6455 - val_loss: 0.6574
# Epoch 1215/1500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.6455 - val_loss: 0.6570
# Epoch 1216/1500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.6454 - val_loss: 0.6571
# Epoch 1217/1500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.6454 - val_loss: 0.6575
# Epoch 1218/1500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.6454 - val_loss: 0.6575
# Epoch 1219/1500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.6454 - val_loss: 0.6570

# %%
mae_optimized = []
mae_dnn = []
mae_lr = []
for i, key in zip(range(6), products):
    print(key)
    pred = dnn[key].predict(X_validate)
    mae_dnn.append(round(mean_absolute_error(pred, y_validate[:,i]),2))
    mae_lr.append(round(mean_absolute_error(purchase_prediction[key]['model'].predict(X_validate), y_validate[:,i]),2))
    mae_optimized.append(round(mean_absolute_error(optimized_models[key].predict(X_validate), y_validate[:,i]),2))

position = np.arange(len(mae_dnn))
width = 0.15
multiplier = 0
mae = [mae_optimized, mae_dnn, mae_lr]
label = ['Optimized DNN', 'DNN', 'LR']
colors = ['black', 'slategrey', 'lightsteelblue']
for i in range(3):
    plt.bar(position + width*multiplier, mae[i], width = width, label = label[i], color = colors[i])
    multiplier += 1

plt.xticks(position + width/2, products)
plt.title('Validation MAE comparison\n(lower is better)')
plt.xlabel('Product')
plt.ylabel('MAE')
plt.legend()
# Out:
# Wines
# 12/12 [==============================] - 0s 1ms/step
# 12/12 [==============================] - 0s 1ms/step
# Fruits
# 12/12 [==============================] - 0s 2ms/step
# 12/12 [==============================] - 0s 1ms/step
# Meat
# 12/12 [==============================] - 0s 1ms/step
# 12/12 [==============================] - 0s 1ms/step
# Fish
# 12/12 [==============================] - 0s 1ms/step
# 12/12 [==============================] - 0s 1ms/step
# Sweet
# 12/12 [==============================] - 0s 1ms/step
# 12/12 [==============================] - 0s 1ms/step
# Gold
# 12/12 [==============================] - 0s 1ms/step
# 12/12 [==============================] - 0s 2ms/step

# %% [markdown]
# Seems like we have little to no improvement. So we can leave our primary model.<br>
# <br>
# Now that models are prepared we can use them for targeting. Oposed to most popular methods, like clustering<br>
# and segmentation to devide customers and look for their distinct features, I will just use income and predicted<br>
# consumption to rank all the customers individually by their potential. We have observed that income is highly correalated<br>
# with more purchases. So we will look for customers who consume low but have high income.

# %%
income_scaler = StandardScaler()
scaled_income = income_scaler.fit_transform(data[['Income']])

consumption_scaler = StandardScaler()
scaled_consumption = consumption_scaler.fit_transform(data[['Wines','Fruits', 'Meat', 'Fish', 'Sweet', 'Gold']])

# %%
scaled_consumption = pd.DataFrame(scaled_consumption, columns = ['Wines','Fruits', 'Meat', 'Fish', 'Sweet', 'Gold'])
scaled_consumption['ID'] = data['ID'].values
scaled_income = pd.DataFrame(scaled_income, columns = ['Income'])
scaled_income['ID'] = data['ID'].values

# %% [markdown]
# I will be using distance between consumption and income to measure how much potential there is.<br>
# For example, if the customer's income is way bigger and has positive standard deviaton of 2 but the consumption deviation is -2<br>
# indicating lower consumption than usual, we will have distance of (2 - (-2)) = 4, indicating quite high potential.<br>
# If customer has high income, for example as previous 2 std, but it also consumes more than usual for example 1 std,<br>
# than we will have less distance (2 - 1) = 1, indicating that potential is lower. Also it could indicate overconsuming customers<br>
# for example, if their income is not that high for example -1 but they consume more 1 std. Distance will be <br>
# (-1-1) = -2, indicating that they consume way more than usual and has low potential.

# %%
target = pd.DataFrame()
for i in scaled_consumption.columns:
    if i != 'ID':
        target[f'{i}'] = scaled_income['Income'] -  scaled_consumption[i]
target.index = scaled_consumption['ID'].values

# %% [markdown]
# Now we can sort by desired product category and set the threshold to filter customer ids.

# %%
target[target['Wines'] > 0]['Wines'].sort_values(ascending = False)
# Out:
# 2535     2.325347
# 7872     2.209750
# 4828     2.197349
# 6906     2.151623
# 7828     2.105394
#            ...
# 10260    0.001809
# 2262     0.001809
# 8652     0.000212
# 4939     0.000212
# 2782     0.000144
# Name: Wines, Length: 941, dtype: float64

# %% [markdown]
# Now I will use our deep neural network (dnn) to determine what consumption we could expect and compare it to actual customer purchases.<br>
# The ones who are consuming less than predicted might be potential targets.

# %%
pred_consumption = pd.DataFrame()
for i, key in zip(range(6), products):
    pred = dnn[key].predict(scaled_data)
    pred_consumption[key] = pred.flatten()
# Out:
# 60/60 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 927us/step
# 60/60 [==============================] - 0s 911us/step

# %% [markdown]
# Now we can calculate distance between predicted and actual.

# %%
target2 = pd.DataFrame()
for i in products:
    target2[i] = pred_consumption[i] -  scaled_consumption[i]
target2.index = scaled_consumption['ID'].values
target2['Wines'][target2['Wines'] > 0].sort_values(ascending=False)
# Out:
# 7872     2.430863
# 2535     2.372890
# 6906     2.360861
# 10473    2.339814
# 10446    2.268117
#            ...
# 1951     0.000933
# 2634     0.000615
# 8969     0.000597
# 89       0.000409
# 2098     0.000302
# Name: Wines, Length: 906, dtype: float64

# %% [markdown]
# Now we have two lists of same customers - those who have high potential by income and those who consume less than average.<br>
# I will filter customers who fall in both groups.

# %%
customers_std = set(target[target['Wines'] > 0]['Wines'].sort_values(ascending = False).index.values)
customers_dnn = set(target2[target2['Wines'] > 0]['Wines'].sort_values(ascending = False).index.values)

# %%
same_customers = customers_std.intersection(customers_dnn)
print('Total customers by std:', len(customers_std))
print('Total customers by actual value:', len(customers_dnn))
print('Same customers', len(same_customers)/len(customers_std))
# Out:
# Total customers by std: 941
# Total customers by actual value: 906
# Same customers 0.7236981934112646

# %% [markdown]
# We can see that about 72% customers intersect. That means they have high income and consuming less than average.<br>
# We can calculate how potentialy we could expect from them to increase in consumption assuming they can reach the average level.

# %%
pred_consumption_amount = consumption_scaler.inverse_transform(pred_consumption)
difference = pred_consumption_amount - data[products]
difference.set_index(data['ID'], inplace=True)
difference.loc[np.array(same_customers)]['Wines'].sum()
# Out:
# 73666.54843378067

# %% [markdown]
# Assuming that customers can reach current average level of consumption, we could expect an increase of income over two years by 73666.

# %% [markdown]
# <font size="5">Conclusion</font><br>

# %% [markdown]
# What we learned about the customers:<br>
# 1. More wealthy people consume more in general. They are more likely to shop at the stores or using catalogues. They are more likely to buy wines and meat and participate in marketing campaigns.<br>
# 2. People with kids consume less and are more likely to shop at the web. They also are more likely to use 'deals'.<br>
#
# Suggestions:<br>
# 1. Meat and wines usually are bought together, so they could be placed near each other at the store.
# 2. As meat and wines are consumed more by wealthy people, who use store and catalogues, campaigns should focus on these channels to reach the customers.<br>
# 3. Customers with kids at home are more using internet and looking for deals, so deals on the web should focus more on the products like fruits, fish.<br>
# 4. In general more purchases are made in physical store, so it is important to maintain customer experience there.
